# %%
import requests
from PIL import Image

# %%
KEY = "5f47d596a70445c599391658743da07d"

# %%
assert KEY

# %%
face_api_url = 'https://20211128.cognitiveservices.azure.com/' + '/face/v1.0/detect'

# %%
Image.open('/Users/yanazawaitoshi/OneDrive - Yokohama City University/あそび/face_detection/1629029.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=1040x760 at 0x10E7DAB20>

# %%
with open('/Users/yanazawaitoshi/OneDrive - Yokohama City University/あそび/face_detection/1629029.png','rb') as f:
    binary_img = f.read()

# %%
binary_img

# %%
headers = {
    'Content-Type':'application/octet-stream',
    'Ocp-Apim-Subscription-Key': KEY
    }

params = {
    'returnFaceAttributes': 'age,gender,smile,facialHair,headPose,glasses',
    'returnFaceId': 'true'
}

response = requests.post(face_api_url, params=params,
headers=headers, data=binary_img
)

# %%
response
# Out:
# <Response [200]>

# %%
result = response.json()
result
# Out:
# [{'faceId': '2935f8e7-d08b-40db-80cb-78c29cd42969',
#   'faceRectangle': {'top': 163, 'left': 379, 'width': 280, 'height': 280},
#   'faceAttributes': {'smile': 0.996,
#    'headPose': {'pitch': 3.4, 'roll': 0.1, 'yaw': 2.0},
#    'gender': 'male',
#    'age': 27.0,
#    'facialHair': {'moustache': 0.4, 'beard': 0.4, 'sideburns': 0.1},
#    'glasses': 'NoGlasses'}}]

# %%
rect = result[0]['faceRectangle']
rect
# Out:
# {'top': 163, 'left': 379, 'width': 280, 'height': 280}

# %%
from PIL import ImageDraw

# %%
img = Image.open('/Users/yanazawaitoshi/OneDrive - Yokohama City University/あそび/face_detection/1629029.png')
draw = ImageDraw.Draw(img)

# %%
draw.rectangle([(rect['left'],rect['top']),(rect['left']+rect['width'],rect['top']+rect['height'])],
fill=None, outline='green',width=5)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=1040x760 at 0x111A35610>

# %%
import requests
from PIL import Image
import io

KEY = "5f47d596a70445c599391658743da07d"
assert KEY

face_api_url = 'https://20211128.cognitiveservices.azure.com/' + '/face/v1.0/detect'

img = Image.open('/Users/yanazawaitoshi/OneDrive - Yokohama City University/あそび/face_detection/1629029.png')

with io.BytesIO() as output:
    img.save(output, format='JPEG')
    binary_img = output.getvalue()

headers = {
    'Content-Type':'application/octet-stream',
    'Ocp-Apim-Subscription-Key': KEY
    }

params = {
    'returnFaceAttributes': 'age,gender,smile,facialHair,headPose,glasses',
    'returnFaceId': 'true'
}

response = requests.post(face_api_url, params=params,
headers=headers, data=binary_img
)

results = response.json()

for result in results:
    result = result['faceRectangle']

    draw = ImageDraw.Draw(img)
    draw.rectangle([(rect['left'],rect['top']),(rect['left']+rect['width'],rect['top']+rect['height'])],
    fill=None, outline='green',width=5)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=1040x760 at 0x111AEB640>

# %%
import io

# %%
with io.BytesIO() as output:
    img.save(output, format='JPEG')
    binary_img = output.getvalue()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.8/site-packages/PIL/Image.py in save(self, fp, format, **params)
#    2137             try:
# -> 2138                 format = EXTENSION[ext]
#    2139             except KeyError as e:
#
# KeyError: ''
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# /var/folders/vr/3vzmlr9x7kl4wpz007pmmd540000gn/T/ipykernel_1209/1766196967.py in <module>
#       1 with io.BytesIO() as output:
# ----> 2     img.save(output)
#
# /usr/local/lib/python3.8/site-packages/PIL/Image.py in save(self, fp, format, **params)
#    2138                 format = EXTENSION[ext]
#    2139             except KeyError as e:
# -> 2140                 raise ValueError("unknown file extension: {}".format(ext)) from e
#    2141
# ...
